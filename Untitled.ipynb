# %%
import pandas as pd
import pickle

# %%
df = pickle.load(open("BC2021_100k.p", "rb"))
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-4086c417f7e7> in <module>()
# ----> 1 df = pickle.load(open("BC2021_100k.p", "rb"))
#       2 print(df.head())
#
# /Users/John/anaconda2/lib/python2.7/pickle.pyc in load(file)
#    1382
#    1383 def load(file):
# -> 1384     return Unpickler(file).load()
#    1385
#    1386 def loads(str):
#
# /Users/John/anaconda2/lib/python2.7/pickle.pyc in load(self)
#     862             while 1:
#     863                 key = read(1)
# --> 864                 dispatch[key](self)
#     865         except _Stop, stopinst:
#     866             return stopinst.value
#
# /Users/John/anaconda2/lib/python2.7/pickle.pyc in load_proto(self)
#     890         proto = ord(self.read(1))
#     891         if not 0 <= proto <= 2:
# --> 892             raise ValueError, "unsupported pickle protocol: %d" % proto
# ...
